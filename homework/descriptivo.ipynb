# %%
# %%

import pandas as pd  #  type: ignore

df = pd.read_csv("data/house_data.csv")

features = df[
    [
        "bedrooms",
        "bathrooms",
        "sqft_living",
        "sqft_lot",
        "floors",
        "waterfront",
        "condition",
    ]
]

target = df[["price"]]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 5
#       1 # %%
#       2
#       3 import pandas as pd  #  type: ignore
#       4
# ----> 5 df = pd.read_csv("data/house_data.csv")
#       6
#       7 features = df[
#       8     [
#
# File c:\repo\taller-presencial-15-despliegue-de-modelos-de-ml-lsmontoyabe\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\repo\taller-presencial-15-despliegue-de-modelos-de-ml-lsmontoyabe\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\repo\taller-presencial-15-despliegue-de-modelos-de-ml-lsmontoyabe\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\repo\taller-presencial-15-despliegue-de-modelos-de-ml-lsmontoyabe\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\repo\taller-presencial-15-despliegue-de-modelos-de-ml-lsmontoyabe\.venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/house_data.csv'

# %%
"""Build, deploy and access a model using scikit-learn"""

import pickle

import pandas as pd  # type: ignore
from sklearn.linear_model import LinearRegression  # type: ignore

df = pd.read_csv("../files/input/house_data.csv", sep=",")

features = df[
    [
        "bedrooms",
        "bathrooms",
        "sqft_living",
        "sqft_lot",
        "floors",
        "waterfront",
        "condition",
    ]
]

target = df[["price"]]

estimator = LinearRegression()
estimator.fit(features, target)

with open("homework/house_predictor.pkl", "wb") as file:
    pickle.dump(estimator, file)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 27
#      23
#      24 estimator = LinearRegression()
#      25 estimator.fit(features, target)
#      26
# ---> 27 with open("homework/house_predictor.pkl", "wb") as file:
#      28     pickle.dump(estimator, file)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'homework/house_predictor.pkl'

# %%
import pandas as pd  #  type: ignore

df = pd.read_csv("../files/input/house_data.csv")

features = df[
    [
        "bedrooms",
        "bathrooms",
        "sqft_living",
        "sqft_lot",
        "floors",
        "waterfront",
        "condition",
    ]
]

target = df[["price"]]

# %%
# %%
features.bathrooms.value_counts().sort_index().plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 # %%
# ----> 2 features.bathrooms.value_counts().sort_index().plot(kind="bar")
#
# File c:\repo\taller-presencial-15-despliegue-de-modelos-de-ml-lsmontoyabe\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File c:\repo\taller-presencial-15-despliegue-de-modelos-de-ml-lsmontoyabe\.venv\Lib\site-packages\pandas\plotting\_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
#    2255 return module
#
# File c:\repo\taller-presencial-15-despliegue-de-modelos-de-ml-lsmontoyabe\.venv\Lib\site-packages\pandas\plotting\_core.py:2183, in _load_backend(backend)
#    2181         module = importlib.import_module("pandas.plotting._matplotlib")
#    2182     except ImportError:
# -> 2183         raise ImportError(
#    2184             "matplotlib is required for plotting when the "
#    2185             'default backend "matplotlib" is selected.'
#    2186         ) from None
#    2187     return module
#    2189 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
